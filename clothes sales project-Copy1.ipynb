# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("A:\study materials data science\projects\shopping_trends_updated.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df['Age'].unique()
# Out:
# array([55, 19, 50, 21, 45, 46, 63, 27, 26, 57, 53, 30, 61, 65, 64, 25, 52,
#        66, 31, 56, 18, 38, 54, 33, 36, 35, 29, 70, 69, 67, 20, 39, 42, 68,
#        49, 59, 47, 40, 41, 48, 22, 24, 44, 37, 58, 32, 62, 51, 28, 43, 34,
#        23, 60], dtype=int64)

# %%
plt.figure(figsize=(12, 5))
sns.countplot(df, x="Age",palette="viridis", width=0.8)
plt.xticks(rotation=90)
plt.show()

# %%
df['Item Purchased'].value_counts()
# Out:
# Item Purchased
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: count, dtype: int64

# %%
summer_data = df[df['Season'] == 'Summer']
summer_data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 5               6   46    Male       Sneakers     Footwear
# 8               9   26    Male           Coat    Outerwear
# 18             19   52    Male        Sweater     Clothing
# 19             20   66    Male          Pants     Clothing
# 22             23   56    Male          Pants     Clothing
# ...           ...  ...     ...            ...          ...
# 3878         3879   60  Female            Hat  Accessories
# 3886         3887   37  Female        Jewelry  Accessories
# 3892         3893   35  Female        Jewelry  Accessories
# 3895         3896   40  Female         Hoodie     Clothing
# 3898         3899   44  Female          Shoes     Footwear
#
#       Purchase Amount (USD)        Location Size      Color  Season  \
# 5                        20         Wyoming    M      White  Summer
# 8                        97   West Virginia    L     Silver  Summer
# ...

# %%
winter_data = df[df['Season'] == 'Winter']
winter_data
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 0               1   55    Male         Blouse   Clothing
# 1               2   19    Male        Sweater   Clothing
# 7               8   27    Male         Shorts   Clothing
# 11             12   30    Male         Shorts   Clothing
# 12             13   61    Male           Coat  Outerwear
# ...           ...  ...     ...            ...        ...
# 3879         3880   26  Female          Skirt   Clothing
# 3880         3881   42  Female          Shirt   Clothing
# 3885         3886   49  Female          Socks   Clothing
# 3890         3891   35  Female          Shirt   Clothing
# 3891         3892   36  Female          Dress   Clothing
#
#       Purchase Amount (USD)       Location Size     Color  Season  \
# 0                        53       Kentucky    L      Gray  Winter
# 1                        64          Maine    L    Maroon  Winter
# 7                        34      Louisiana    L  Charcoal  Winter
# ...

# %%
spring_data = df[df['Season'] == 'Spring']
spring_data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# 9              10   57    Male        Handbag  Accessories
# 13             14   65    Male          Dress     Clothing
# ...           ...  ...     ...            ...          ...
# 3889         3890   57  Female          Dress     Clothing
# 3894         3895   66  Female          Skirt     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# ...

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Season', y='Purchase Amount (USD)', data=df, ci=None)
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_2056\2219622059.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Season', y='Purchase Amount (USD)', data=df, ci=None)
# <Axes: xlabel='Season', ylabel='Purchase Amount (USD)'>

# %%
plt.figure(figsize=(5, 4))
sns.barplot(x='Season', y='Purchase Amount (USD)', hue='Category', data=df)

# Set plot labels and title
plt.xlabel('Season')
plt.ylabel('Purchase Amount')
plt.title('Purchase Amount by Season and Cloth Category')
# Out:
# Text(0.5, 1.0, 'Purchase Amount by Season and Cloth Category')

# %%
plt.figure(figsize=(8, 14))
sns.countplot(y='Location', data=df,palette="viridis", width=0.8)
plt.xticks(rotation=90)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(0.0, 0, '0'),
#   Text(20.0, 0, '20'),
#   Text(40.0, 0, '40'),
#   Text(60.0, 0, '60'),
#   Text(80.0, 0, '80'),
#   Text(100.0, 0, '100'),
#   Text(120.0, 0, '120')])

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Review Rating', y='Item Purchased', data=df, palette='viridis')
# Out:
# <Axes: xlabel='Review Rating', ylabel='Item Purchased'>

# %%
sns.lineplot(data=df, x="Purchase Amount (USD)", y="Age", hue="Gender", palette="deep")
# Out:
# <Axes: xlabel='Purchase Amount (USD)', ylabel='Age'>

# %%
sns.kdeplot(data=df, x="Purchase Amount (USD)", y="Age")
# Out:
# <Axes: xlabel='Purchase Amount (USD)', ylabel='Age'>

# %%
plt.figure(figsize=(8, 6))
sns.swarmplot(y='Purchase Amount (USD)', x='Frequency of Purchases', data=df, palette='viridis')
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_4668\4134780432.py:2: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(y='Purchase Amount (USD)', x='Frequency of Purchases', data=df, palette='viridis')
# C:\Users\ashwi\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ashwi\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ashwi\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 22.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
